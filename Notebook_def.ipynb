# %% [markdown]
# # Sistema RAG

# %% [markdown]
# ### Moises Bustillo
# En este proyecto, se contruye el sistema RAG completo. Utilizando los pasajes recuperados en la fase de construcción del corpus, decidiendo cuáles de ellos y cómo se le inyectan a la entrada del LLM para mejorar la calidad de la respuesta.

# %% [markdown]
# ## Instalación de librerías necesarias
#
# En esta celda se instalan las librerías básicas que se utilizarán a lo largo del notebook para la **recopilación, procesamiento y análisis de texto**, así como para la generación de **embeddings semánticos** que serán empleados en el modelo de lenguaje.
#
# Las librerías instaladas son:
#
# - `requests` : Para realizar peticiones HTTP y consumir APIs o recursos web de forma programática.
# - `pandas` : Para la manipulación y análisis de datos estructurados en formato tabular.
# - `tqdm` : Para mostrar barras de progreso durante procesos iterativos o tareas de larga duración.
# - `sentence-transformers` : Para generar embeddings de texto utilizando modelos preentrenados basados en transformers, fundamentales para tareas de similitud semántica y recuperación de información.

# %%
! pip install requests
! pip install pandas
! pip install tqdm
! pip install sentence_transformers
# Out:
# Requirement already satisfied: requests in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (2025.10.5)
# Requirement already satisfied: pandas in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: sentence_transformers in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (5.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence_transformers) (4.57.1)
# Requirement already satisfied: tqdm in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence_transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence_transformers) (1.3.2)
# Requirement already satisfied: scipy in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence_transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence_transformers) (0.36.0)
# Requirement already satisfied: Pillow in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence_transformers) (12.0.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sentence_transformers) (4.15.0)
# Requirement already satisfied: filelock in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2025.10.23)
# Requirement already satisfied: requests in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.10.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.11.0->sentence_transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.11.0->sentence_transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm->sentence_transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence_transformers) (2025.10.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->sentence_transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\javito\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn->sentence_transformers) (3.6.0)

# %% [markdown]
# ## Importación de liberías
# Hacemos los imports distintos imports que realizaremos a lo largo del proyecto

# %%
from sentence_transformers import SentenceTransformer, util
from tqdm import tqdm
import pandas as pd
import requests
import random
import torch
import json
import time
import re
import os

# %% [markdown]
# Podemos verificar que Ollama está corriendo

# %%
try:
    response = requests.get('http://localhost:11434')
    if response.status_code == 200 and 'Ollama is running' in response.text:
        print("Ollama está corriendo y accesible")
    else:
        print(f"Ollama respondió con estado {response.status_code}.")
except requests.exceptions.ConnectionError:
    print("Error de Conexión")
# Out:
# Ollama está corriendo y accesible

# %% [markdown]
# ## Configuración general del experimento RAG
#
# En esta sección se definen los **parámetros globales de ejecución** del experimento, incluyendo los archivos de entrada y salida, la variante de generación utilizada (RAG con opción Few-Shot), el modelo de lenguaje empleado en Ollama y el **prompt base** que establece las reglas de comportamiento y formato de las respuestas del modelo.

# %%
# Definimos los valores para el modo RAG (Retrieval-Augmented Generation)

# Archivos de entrada/salida
ESTADO = "test"     # podemos indicar que utilizaremos los datos de train o test para responder a las preguntas.
VARIANTE = "rag"    # nombre de la variante
VARIANTE_FS = True  # indicamos si es few-shot o no

# archivos y configuraciones
ARCHIVO_TRAIN_JSONL = "train.jsonl"
ARCHIVO_TEST = "test.jsonl"
ARCHIVO_CORPUS = "corpus.json"          
OLLAMA_URL = "http://localhost:11434/api/generate"
MODEL = "gemma3:12b"
ARCHIVO_CSV_SALIDA = VARIANTE + ".csv"
NUM_FS_EXAMPLES = 3

PROMPT_BASE = """You are an AI model highly specialized in factual information retrieval. You are operating within the temporal context of 2018. All answers provided must strictly reflect the knowledge, events, and state of affairs valid up to the end of that year.
    Your sole mission is to address the user's question with the absolute minimum number of words possible, delivering only the essential and requested information. If ambiguity arises, assume the user's intended question and prioritize the most probable correct answer without acknowledging the error.
    When an error in the question is identified (e.g., misspelling, wrong movie number) but points to a primary, well-known entity, provide the correct, assumed information directly.
    When the required answer is a date, you must follow the following examples (18 march 2015, 20 december 2008) if you don't know the exact day or month, you can omit it
    Your response must consist solely of the requested facts. Prohibit all greetings, introductions, explanations, notes, or any extraneous text.
    No use of abbreviations, acronyms, or initialisms. Provide full names and complete terms.
    No use of terms of puntuation like . , or ;
    If the answer requires multiple components (e.g., names, locations, dates), you must provide all essential components in their complete form.
    """

# %% [markdown]
# ## Construcción dinámica del prompt para RAG y Few-Shot
#
# En esta sección se definen las funciones responsables de **construir el prompt final** que se enviará al modelo de lenguaje.
# El prompt se compone a partir de las **instrucciones base**, los **pasajes de contexto recuperados** (RAG) y, de forma opcional, **ejemplos Few-Shot** utilizados como guía de estilo.
# Este diseño permite controlar explícitamente la estructura del prompt y adaptar su contenido según la variante de generación utilizada.

# %% [markdown]
# La siguiente función se encarga de montar el prompt.
# Se le pueden enviar una serie de pasajes, una pregunta, un prompt y una serie de ejemplos y monta el prompt.

# %%
def build_prompt_rag(passages, question, PROMPT_BASE, few_shot_examples=None):
    fs_block = ""
    if few_shot_examples:
        fs_block = "\n\n**FEW-SHOT EXAMPLES (Style Guide):**\n"
        for i, ex in enumerate(few_shot_examples):
            fs_block += f"Example {i+1}:\n"
            fs_block += f"  - Question: {ex['question']}\n" 
            
            answer_text = ex['answer']
            if isinstance(answer_text, list):
                answer_text = ", ".join(map(str, answer_text)) 
                
            fs_block += f"  - Answer: {answer_text}\n---\n"
        fs_block += "\n"

    context_lines = []
    context_lines.append("\n\n**EXTERNAL KNOWLEDGE:**\n")

    for p in passages:
        text_content = p.get("text", p.get("texto", "Pasaje sin contenido"))
        context_lines.append(f"Knowledge: {text_content}\n---")
    
    context_block = '\n'.join(context_lines)
        
    prompt = PROMPT_BASE.strip() 
    prompt += fs_block
    prompt += context_block
    
    prompt += f"\n\nFINAL TASK: Based on your internal knowledge and the external information provided above, answer the next question: {question}"
    return prompt

# %% [markdown]
# ## Envío de consultas al modelo mediante Ollama
#
# En esta sección se define la función encargada de **comunicarse con el modelo de lenguaje a través de Ollama**.
# La función construye dinámicamente el prompt según la variante seleccionada (**base**, **Few-Shot** o **RAG**), envía la consulta al modelo con parámetros de generación controlados y gestiona la respuesta en modo *streaming*, incluyendo el tratamiento básico de errores de conexión o ejecución.

# %% [markdown]
# A continuación definimos una función ask_ollama que dada una pregunta, unos pasajes de contexto y unos ejemplos few_shot, llama a la funcion build prompt definida anteriormente y hace una llamada al modelo ollama

# %%
# definimos las opciones del modelo
options = {
        "temperature": 0.05
    }

def ask_ollama(question, context_data = None, few_shot_examples=None):
    if VARIANTE == "rag" and context_data:
        prompt = build_prompt_rag(context_data, question,PROMPT_BASE, few_shot_examples=few_shot_examples)
    else:
        # Prompt base si no hay contexto
        prompt = PROMPT_BASE.format(question=question) 
        
    # print(prompt)
    full_response = ""
    
    try:
        response = requests.post(OLLAMA_URL, json={
            "model": MODEL,
            "prompt": prompt,
            "stream": True,
            "options": options
        }, timeout=120)

        response.raise_for_status()

        for line in response.iter_lines():
            if line:
                part = json.loads(line)
                if "response" in part:
                    full_response += part["response"]
                if part.get("done"):
                    break
        
        return full_response.strip()
        
    except requests.exceptions.ConnectionError:
        return f"[ERROR: Conexión fallida con Ollama en {OLLAMA_URL}]"
    except requests.exceptions.HTTPError as e:
        return f"[ERROR: HTTP {e}. ¿Modelo '{MODEL}' instalado?]"
    except Exception as e:
        return f"[ERROR: Inesperado: {e}]"

# %% [markdown]
# ## Carga y validación de los conjuntos de datos
#
# En esta sección se cargan los **datos de entrenamiento** utilizados para el enfoque **Few-Shot**, las **preguntas de evaluación** desde el conjunto de test y el **corpus de pasajes** que servirá como contexto externo en el modo RAG.
# Además, se realiza una **verificación básica** para comprobar que los archivos se han leído correctamente y que la estructura de los datos es la esperada antes de continuar con el pipeline.

# %%
# Definición de variables necesarias
preguntas_cargadas = [] # El conjunto que se iterará (Test o Train)
train_qa_data = []      # El conjunto (Q,A) usado para Few-Shot (siempre del train)
train_data_rag = []     # El corpus de pasajes para RAG

try:
    # 1. Cargar DATOS QA COMPLETOS (Fuente del Few-Shot)
    with open(ARCHIVO_TRAIN_JSONL, "r", encoding="utf-8") as f:
        for i, line in enumerate(f):
            data = json.loads(line)
            train_qa_data.append({
                "número_pregunta": i + 1,
                "question": data.get("question", ""), 
                "answer": data.get("answer", "") 
            })
    
    print(f"✅ Se cargaron {len(train_qa_data)} pares QA del archivo de entrenamiento (para Few-Shot).")

    # Cargamos las preguntas de test
    test_questions = []
    with open(ARCHIVO_TEST, "r", encoding="utf-8") as f:
        for i, line in enumerate(f):
            data = json.loads(line)
            test_questions.append({
                "número_pregunta": i + 1,
                "pregunta": data.get("question", "")
            })
            
    # Asignamos el conjunto a evaluar
    if ESTADO == "test" :
        preguntas_cargadas = test_questions
    else :
        preguntas_cargadas = train_qa_data
    
    print(f"Se cargaron {len(preguntas_cargadas)} preguntas del archivo a evaluar.")

    # 3. Cargar DATOS DE CONTEXTO RAG (ARCHIVO_CORPUS: Pasajes)
    with open(ARCHIVO_CORPUS, "r", encoding="utf-8") as f:
        train_data_rag = json.load(f)
    
    if isinstance(train_data_rag, list):
        print(f"Se cargaron {len(train_data_rag)} pasajes (Contexto RAG) de \"{ARCHIVO_CORPUS}\".")
    else:
        print(f"ADVERTENCIA: El archivo '{ARCHIVO_CORPUS}' no es una lista ({type(train_data_rag)}).")

except FileNotFoundError as e:
    print(f"ERROR: El archivo '{e.filename}' no se encontró. ¡Verifica la ruta!")
    preguntas_cargadas = None
except json.JSONDecodeError as e:
    print(f"ERROR: Fallo al decodificar JSON en uno de los archivos. Detalle: {e}")
    preguntas_cargadas = None


# --- Verificación de Carga ---
if preguntas_cargadas and train_data_rag and isinstance(train_data_rag, list) and len(train_data_rag) > 0:
    print("\n--- Verificación de Datos ---")
    
    # Conjunto a iterar (TEST)
    print("Primeras 3 preguntas de TEST cargadas:")
    for item in preguntas_cargadas[:3]:
        print(f"  {item['número_pregunta']}: {item['pregunta'][:50]}...")
    
    # Conjunto para Few-Shot (TRAIN QA)
    print("\nPrimeros 3 ejemplos Few-Shot (Q, A) cargados (del train):")
    for item in train_qa_data[:3]:
        print(f"  Q: {item['question'][:50]}... | A: {item['answer']}")
    
    # Corpus RAG
    ejemplo_completo = train_data_rag[0]
    texto_pasaje = ejemplo_completo.get('text', ejemplo_completo.get('texto', 'N/A'))
    print("\nVerificación de un ejemplo de CONTEXTO RAG (Pasaje):")
    print(f"  Pasaje ID: {ejemplo_completo.get('id', 'N/A')}")
    print(f"  Contenido (Inicio): {texto_pasaje[:100]}...")
# Out:
# ✅ Se cargaron 100 pares QA del archivo de entrenamiento (para Few-Shot).
# ✅ Se cargaron 50 preguntas del archivo de test (a evaluar).
# ✅ Se cargaron 6928 pasajes (Contexto RAG) de "corpus.json".
#
# --- Verificación de Datos ---
# Primeras 3 preguntas de TEST cargadas:
#   1: who played rum tum tugger in the movie cats...
#   2: how many states play in the mega millions lottery...
#   3: when did america switch from tea to coffee...
#
# Primeros 3 ejemplos Few-Shot (Q, A) cargados (del train):
#   Q: where did the vietnam war mainly take place... | A: ['Cambodia', 'Vietnam', 'Laos']
#   Q: when was krakauer considered a success as a writer... | A: ['November 1983']
#   Q: who played mrs garrett's son on facts of life... | A: ['Tom Fitzsimmons', 'Joel Brooks']
#
# Verificación de un ejemplo de CONTEXTO RAG (Pasaje):
#   Pasaje ID: 064_001
#   Contenido (Inicio): 1815. The Battle of Waterloowas a very importantbattle fought in 1815. It was between the French arm...

# %% [markdown]
# ## Generación y carga de embeddings del corpus
#
# En esta sección se preparan los **embeddings semánticos del corpus de pasajes** que serán utilizados en el modo RAG.
# El proceso detecta automáticamente si hay **GPU disponible** para acelerar el cálculo y reutiliza una **caché de embeddings** si ya ha sido generada previamente, evitando recomputaciones innecesarias.
# Si la caché no existe, los embeddings se calculan a partir del texto del corpus y se almacenan para su uso en ejecuciones posteriores.

# %%
# Determina el dispositivo ('cuda' si hay GPU, 'cpu' si no)
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Dispositivo de procesamiento seleccionado: {DEVICE}")

# Definir la ruta del caché y el modelo de embeddings
EMBEDDINGS_CACHE_FILE = "corpus_embeddings_mpnet.pt" 
text_key = "texto"

# Inicializar el modelo explícitamente en el dispositivo detectado
model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2", device=DEVICE)
print(f"Modelo de embeddings cargado en el dispositivo: {DEVICE}")

train_data = train_data_rag # El corpus de pasajes

# --- 1. PREPARACIÓN DE EMBEDDINGS RAG (CON CACHE) ---
train_embeddings = None
num_pasajes = 0 

if VARIANTE == "rag":
    print("entramos a la preparación de embeddings RAG")
    
    # Intenta cargar los embeddings si el archivo existe
    try:
        if os.path.exists(EMBEDDINGS_CACHE_FILE):
            print(f"Cargando embeddings desde la caché: {EMBEDDINGS_CACHE_FILE}")
            # Cargamos el tensor en el dispositivo correcto
            train_embeddings = torch.load(EMBEDDINGS_CACHE_FILE, map_location=DEVICE)
            num_pasajes = len(train_data)
            print("Embeddings cargados rápidamente.")
        else:
            # Si no existe, los codificamos
            print("Caché no encontrada. Codificando embeddings del corpus de pasajes (Puede tardar)...")
            if train_data and isinstance(train_data, list) and text_key in train_data[0]:
                train_texts = [ex.get(text_key, "") for ex in train_data]
                train_embeddings = model.encode(train_texts, convert_to_tensor=True, show_progress_bar=True)
                num_pasajes = len(train_data)

                torch.save(train_embeddings, EMBEDDINGS_CACHE_FILE)
                print(f"Embeddings guardados en la caché: {EMBEDDINGS_CACHE_FILE}")
            else:
                print(f"ERROR CRÍTICO: La clave '{text_key}' no se encontró en el corpus para RAG.")
                train_embeddings = None
    except Exception as e:
        print(f"ERROR al cargar/guardar la caché de embeddings: {e}")
        train_embeddings = None
# Out:
# Dispositivo de procesamiento seleccionado: cpu
# Modelo de embeddings cargado en el dispositivo: cpu
# entramos a la preparación de embeddings RAG
# 🔄 Cargando embeddings desde la caché: corpus_embeddings_mpnet.pt
# ✅ Embeddings cargados rápidamente.

# %% [markdown]
# ## Ejecución del pipeline RAG con recuperación híbrida
#
# En esta sección se ejecuta el **bucle principal de evaluación**. Para cada pregunta de test, se recupera un conjunto de pasajes de contexto combinando **búsqueda semántica por similitud** y **muestreo aleatorio**, generando así un contexto híbrido.
# Opcionalmente, se incorporan **ejemplos Few-Shot** desde el conjunto de entrenamiento.
# Cada pregunta, junto con su contexto, se envía al modelo de lenguaje a través de Ollama, se limpia la salida generada y los resultados se almacenan de forma incremental en un archivo CSV para su posterior análisis.

# %%
# Detecta el dispositivo
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# --- CONFIGURACIÓN DE RECUPERACIÓN HÍBRIDA ---
# A continuación indicamos cuantos pasajes similares y cuantos aleatorios añadir
K_SIMILAR = 25 
K_RANDOM = 3
HEADERS = ["número_pregunta", "pregunta", "salida_llm", "nombre_variante"]

# Variables de control del loop
es_primera_escritura = True

if preguntas_cargadas is None:
    print("No se puede ejecutar el bucle porque las preguntas no se cargaron correctamente.")
elif train_embeddings is None:
    print("No se puede ejecutar el bucle RAG porque los embeddings no se cargaron correctamente.")
else:
    print(f"\nIniciando consulta al LLM con la variante RAG (Híbrida: {K_SIMILAR} Similares + {K_RANDOM} Aleatorio) en {DEVICE}...")
    
    # --- 2. BUCLE DE PROCESAMIENTO ---
    for item in tqdm(preguntas_cargadas, desc="Procesando Preguntas"):
     
     numero_pregunta = item["número_pregunta"]
     question = item["pregunta"]
     
     context_data = [] 
     similar_indices = []

     if VARIANTE == "rag" and train_embeddings is not None:
         
         # --- A. RECUPERACIÓN SEMÁNTICA (K_SIMILAR) ---
         
         test_embedding = model.encode(question, convert_to_tensor=True)
         
         if DEVICE == 'cuda':
            test_embedding = test_embedding.to(DEVICE)
         
         cos_scores = util.pytorch_cos_sim(test_embedding, train_embeddings)[0]
         
         top_results = cos_scores.topk(K_SIMILAR)
         similar_indices = top_results[1].tolist()
         
         context_similar = [train_data[idx] for idx in similar_indices]
         context_data.extend(context_similar)
         
         # --- B. RECUPERACIÓN ALEATORIA (K_RANDOM) ---
         all_indices = set(range(num_pasajes))
         used_indices = set(similar_indices)
         available_indices = list(all_indices - used_indices)
         
         k_to_sample = min(K_RANDOM, len(available_indices))
         
         if k_to_sample > 0:
           random_indices = random.sample(available_indices, k_to_sample)
         else:
           random_indices = []
         
         context_random = [train_data[idx] for idx in random_indices]
         context_data.extend(context_random)
     # si Variante_fs es true añadimos ejemplos de pregunta respuesta
     if VARIANTE_FS:
        num_qa_examples = len(train_qa_data) 
        k_fs_sample = min(NUM_FS_EXAMPLES, num_qa_examples)
        
        if k_fs_sample > 0:
            fs_indices = random.sample(range(num_qa_examples), k_fs_sample)
            
            # Extraer de train_qa_data
            few_shot_examples = [train_qa_data[idx] for idx in fs_indices]
     
     
     # Se pasa la pregunta y los pasajes recuperados al LLM
     salida_llm = ask_ollama(question, context_data=context_data,few_shot_examples=few_shot_examples)
     
     # LIMPIEZA ADICIONAL
     salida_llm = re.sub(r'\s+', ' ', salida_llm).strip()
     salida_llm = re.sub(r'[.,;:]', '', salida_llm).strip()
     
     # Creación del DataFrame de la fila
     df_fila = pd.DataFrame([{
         "número_pregunta": numero_pregunta,
         "pregunta": question,
         "salida_llm": salida_llm,
         "nombre_variante": VARIANTE
     }], columns=HEADERS)
     
     # Lógica de guardado incremental en CSV
     modo_escritura = 'w' if es_primera_escritura else 'a'
     
     try:
         # Crea el archivo con encabezados solo en la primera iteración
         if es_primera_escritura:
           pd.DataFrame(columns=HEADERS).to_csv(ARCHIVO_CSV_SALIDA, mode='w', header=False, index=False, encoding='utf-8')
           modo_escritura = 'a'
         
         df_fila.to_csv(
          ARCHIVO_CSV_SALIDA,
          mode='a', 
          header=False,     
          index=False,
          encoding='utf-8',
          lineterminator='\n'  
         )
         es_primera_escritura = False 
     except Exception as e:
         print(f"\nERROR al guardar la pregunta {numero_pregunta} en CSV: {e}")
         
     time.sleep(0.1)

    print(f"\nEvaluación finalizada. Revisa el archivo '{ARCHIVO_CSV_SALIDA}'.")
# Out:
# Iniciando consulta al LLM con la variante RAG (Híbrida: 25 Similares + 3 Aleatorio) en cpu...
# Procesando Preguntas:   0%|          | 0/50 [00:00<?, ?it/s]
# You are an AI model highly specialized in factual information retrieval. You are operating within the temporal context of 2018. All answers provided must strictly reflect the knowledge, events, and state of affairs valid up to the end of that year.
#     Your sole mission is to address the user's question with the absolute minimum number of words possible, delivering only the essential and requested information. If ambiguity arises, assume the user's intended question and prioritize the most probable correct answer without acknowledging the error.
#     When an error in the question is identified (e.g., misspelling, wrong movie number) but points to a primary, well-known entity, provide the correct, assumed information directly.
#     When the required answer is a date, you must follow the following examples (18 march 2015, 20 december 2008) if you don't know the exact day or month, you can omit it
#     Your response must consist solely of the requested facts. Prohibit all greetings, introductions, explanations, notes, or any extraneous text.
#     No use of abbreviations, acronyms, or initialisms. Provide full names and complete terms.
#     No use of terms of puntuation like . , or ;
#     If the answer requires multiple components (e.g., names, locations, dates), you must provide all essential components in their complete form.
#
# **FEW-SHOT EXAMPLES (Style Guide):**
# Example 1:
#   - Question: who won coach trip road to ibiza 2016
#   - Answer: Holmest & Lauryn
# ---
# Example 2:
#   - Question: who is piper from orange is the new black married to
#   - Answer: Larry Smith
# ---
# Example 3:
#   - Question: who has been appointed as the new chancellor of nalanda university
#   - Answer: Dr. Vijay Pandurang Bhatkar
# ---
#
#
#
# **EXTERNAL KNOWLEDGE:**
#
# Knowledge: Rum Tum tugger played a character in the 1980 movie cats. It was released in the United States on December 2, 1980. The movie was a remake of the 1980 movie cats. The name of the actor that played rum tum tugger in the 1980 movie cats is 'Rum Tum'.
# ---
# Knowledge: John Partridge took on the role, delivering a captivating performance that showcased his exceptional skills as a performer. The answer to the question of who played Rum Tum Tugger in Cats can be found in the 1998 video adaptation of the musical.
# ---
# Knowledge: Rum Tum tugger is a character in the film cats. He played rum tum in the movie cats. The answer: Rum Tum. (born 1959). br> /br> /br>
# ---
# Knowledge: Rum tum tugger is a character in the movie cats. It was played by rum tum. the name of the character in the movie cats is Macavity. the name of the character in the movie cats is Grizabella.
# ---
# Knowledge: Jason Derulo plays Rum Tum Tugger in the new movie Cats. The singer, who plays Rum Tum Tugger in the new movie, talks about his costume and whether or not he'll be adding Cats tunes to his set lists.
# ---
# Knowledge: Jason Derulo played Rum Tum Tugger. The 2019 film adaptation of the film, The Cats, was filmed in North Carolina. The movie was directed by Jason Derulo. Rum Tum Tugger is a rebellious Jellicle cat who loves to be the center of attention.
# ---
# Knowledge: John Partridge is a performer. He played Rum Tum Tugger in the 1998 video adaptation of the musical Cats. The answer to the question of who played Rum Tum Tugger in Cats can be found in the 1998 video adaptation of the musical.
# ---
# Knowledge: Two stars played rum tum tugger in the movie cats..two stars played rum tum tugger in the movie cats..two stars played rum tum tugger in the movie cats..two stars played rum tum tugger in the movie cats..
# ---
# Knowledge: Jason Derulo would return to the screen. The 30-year-old singer turned TikTokstar played the role of Rum Tum Tugger. who played Rum Tum Tugger in the movie cats?. a re-tweet
# ---
Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania, Pennsylvania
# ---
# Knowledge: six participating states. is offered in 45 states, the District of Columbia, and the U.S. Virgin Islands. The first (The Big Game) Mega Millions drawing was in 2002. the Mega Millions is a lottery game that has six participating states.
# ---
# Knowledge: The US Mega Millions Lotteryis the all American multi-state lotto game. Covering 43 states from one end of the USA to the other, the Mega Millions Lottery offers nine ways to win and MEGA jackpots.
# ---
# Knowledge: Mega Millions is a multistate lottery in the United States. You can purchase tickets for the Mega Millions Lottery inall but five statesplus the U.S. territories of Washington, DC and the U.S. Virgin Islands.
# ---
# Knowledge: Mega Millions is available to play in 45 states, the District of Columbia, and the U.S. Virgin Islands. There were six participating states – Georgia, Illinois, Maryland, Massachusetts, Michigan and Virginia – for the first draw in August 1996
# ---
# Knowledge: Mega Millions is played in 45 states. Mega Millions is played in 45 states. The jackpot prize is split equally among winning Jackpot Prize plays. Each Jackpot Prize share that has a cash value of less than $1,000,000 will be paid in a single payment.
# ---
# Knowledge: 45 states plus the District of Columbia and the U.S. Virgin Islands.. a list of state-by-state mega millions odds and a list of state-by-state odds and a list of state-by-state odds and a list of state-by-state odds and a list of state-by-state odds and a list of state-by-state odds
# ---
# Knowledge: Mega Millions is an exciting multi-state lottery played every Tuesday and Friday evening across 45 states, plus the District of Columbia and U.S. Virgin Islands jurisdictions. It's exciting because every prize you win will be multiplied!
# ---
# Knowledge: Mega Millions: Mega Millions is a lottery that is played in 32 states. It has a jackpot of $900 million. It is the second largest lottery in the world, behind the American Lottery, which has won $45 million.
# ---
# Knowledge: 45 states plus the District of Columbia and the U. S. Virgin Islands, you can play Mega Millions in what country?. The game is played in what city?. The game is played in what country?. The game is played in what country?
# ---
# Knowledge: 45 states plus the District of Columbia and the U.S. Virgin Islands. state. to get contact information or link to that lottery's website. to win the Mega Millions lottery. to win the Mega Millions lottery. to win the Mega Millions lottery.
# ---
# Knowledge: 44 states. The game is available in Washington, D.C., and the U.S. in June 2019. As of June 2019, Mega Millions is available in 44 states. The game is also available in Washington, D.C., and the U.S. in June 2019.
# ---
# Knowledge: 45 states, the District of Columbia, and the U.S. Virgin Islands. . The MegaMillions draws are held twice a week, providing multiple chances to win. . The MegaMillions draws are held twice a week, providing multiple chances to win. .
# ---
# Knowledge: Multi-state lottery held in the United States twice a week. The Mega Millions numbers are announced on the Tuesday or Friday draw. Which state does Mega Millions take place in?. . How many states are in the United States?
# ---
# Knowledge: 45 states, plus the District of Columbia and U.S. Virgin Islands jurisdictions.. is the largest multi-state lottery in the world.. it is an exciting multi-state lottery played every Tuesday and Friday evening across 45 states..
# ---
# Knowledge: six participating states, Georgia, Illinois, Maryland, Michigan, Massachusetts, and Virginia. The first (The Big Game) Mega Millions drawing was in 2002. The minimum Mega Millions advertisedjackpotis $50 million, paid in 30 graduated yearly installments, increasing 5% each year (unless the cash option is chosen).
# ---
# Knowledge: 45 states play in the Mega Millions lottery. You must be 18 years of age or older to win. The jackpot prize is split among winning Jackpot Prize plays. Each Jackpot Prize share that has a cash value of less than $1,000,000 will be paid in a single payment.
# ---
# Knowledge: Multi-state lottery is held in the United States twice a week. Each drawing offers up jackpots over $300 million. The jackpots are higher than the Mega Ball. You can win $10 million without matching all the numbers. The Megaplier was removed and replaced with a built-in multiplier.
# ---
# Knowledge: Mega Millions is played in 47 jurisdictions. How many states are in the game?. How many states play in Mega Millions?. How many states play Mega Millions in?.. How many states play Mega Millions in?.
# ---
# Knowledge: Mega Millions in 47 states. Read the Mega Millions Checker. Play Mega Millions. Win a Mega Millions Prize. Play Mega Millions. Win a Mega Millions Prize. Win a Mega Millions Prize. Play Mega Millions.
# ---
# Knowledge: – The mega millions lottery was launched in 2000. Now, the numbers are even higher. The numbers are up to 25,000. But the numbers are going to be even higher. The winner has the power to choose a number of states and a specific number of winners. The winners can choose between a small number of states or a large number of states. The winners have to make a winning choice. The winner of the Mega Millions lottery will win the largest prize in history. The winner can also choose to win more than $500,000.
# ---
# Knowledge: Multi-state lotteries are popular in the United States. MegaMillions has a jackpot of more than $1.6 billion. The jackpot is the most popular of all the multi-state lotteries in the United States. The average payout is between $1.2 million and $1,000,000.
# ---
# Knowledge: There are 45 states across America, as well as the District of Columbia and U.S. Virgin Islands. Yes. There are a number of providers on the Internet who allow you to play MegaMillions from the UK. Who can buy your ticket?
# ---
# Knowledge: The Civil Services Examination (CSE) 2025exam cycle will begin on May 25th, 2025 with the prelims exam conducted by the Union Public Service Commission (UPSC). It is essential for candidates to be well aware of the eligibility criteria, including the age limit, before applying for the UPSC 2025 exam.
# ---
# Knowledge: season three, episode three, "Walk With Me" . Rick's squaring off against him proved to be the first time the survivors were forced to face an even larger and more organized group than themselves- and get a glimpse of how other survivors were reckoning with the world.
# ---
# Knowledge: the elderly and disabled.. this Act establishes a regulatory framework for care services within the UK, creating the National Care Standards Commission to oversee the registration and inspection of care homes, nursing agencies, and other care facilities.. is a reference to
# ---
#
# FINAL TASK: Based on your internal knowledge and the external information provided above, answer the next question: how many states play in the mega millions lottery
# Procesando Preguntas:   4%|▍         | 2/50 [00:07<02:58,  3.72s/it]
# You are an AI model highly specialized in factual information retrieval. You are operating within the temporal context of 2018. All answers provided must strictly reflect the knowledge, events, and state of affairs valid up to the end of that year.
#     Your sole mission is to address the user's question with the absolute minimum number of words possible, delivering only the essential and requested information. If ambiguity arises, assume the user's intended question and prioritize the most probable correct answer without acknowledging the error.
#     When an error in the question is identified (e.g., misspelling, wrong movie number) but points to a primary, well-known entity, provide the correct, assumed information directly.
#     When the required answer is a date, you must follow the following examples (18 march 2015, 20 december 2008) if you don't know the exact day or month, you can omit it
#     Your response must consist solely of the requested facts. Prohibit all greetings, introductions, explanations, notes, or any extraneous text.
#     No use of abbreviations, acronyms, or initialisms. Provide full names and complete terms.
#     No use of terms of puntuation like . , or ;
#     If the answer requires multiple components (e.g., names, locations, dates), you must provide all essential components in their complete form.
#
# **FEW-SHOT EXAMPLES (Style Guide):**
# Example 1:
#   - Question: what is the latest version on mac os
#   - Answer: macOS High Sierra
# ---
# Example 2:
#   - Question: who is woody from toy story based on
#   - Answer: former Disney animator, Tone Thyne
# ---
# Example 3:
#   - Question: what type of basketball is used in the nba
#   - Answer: Spalding
# ---
#
#
#
# **EXTERNAL KNOWLEDGE:**
#
# Knowledge: By the time the 18th century rolled around, and talk of revolution started percolating, Americans were beginning to shift their tastes. Once the Boston Tea Party happened in 1773, drinking tea was seen as a sign of loyalty to the Crown. So, many Americans switched from tea to coffee, and the drink took off.
# ---
# Knowledge: December 16, 1773. In the wake of the Boston Tea Party, drinking British tea became unpatriotic. Enter coffee! Almost overnight, coffee became the new beverage of choice. Colonists saw it as a way to stick it to the British and support the cause of independence.
# ---
# Knowledge: 1850s and 1960s. It was seen as patriotic to switch from drinking tea to drinking coffee. 1860s and 1960s. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# 
# ---
# Knowledge: middle of the 17th century. Coffee was first brought to America by the British during their colonization of the new world in the middle of the 17th century. Theodore Roosevelt, Theodore Roosevelt, and Theodore Roosevelt. Coffee was first brought to America by the British during their colonization of the new world in the middle of the 17th century.
# ---
# Knowledge: introduction of the commodity to North America in the 17th century. at that time, the British and Dutch colonies imported coffee to drink in exclusive coffee houses. Into the 1700s, the British East India Company had worked hard to take advantage of the North American market for tea.
# ---
# Knowledge: Coffee has been popular in America for decades, but coffee has recently become the most popular drink. The main reason for this shift is likely due to coffee's ability to provide energy and wakefulness throughout the day. The country's drink industry is mostly made up of people who are used to drinking tea.
# ---
# Knowledge: The third wave of coffee was the first time that Americans switched from tea to coffee. The second wave of coffee was the first time that Americans switched from tea to coffee. The answer: The third wave of coffee was the first time that Americans switched from tea to coffee.
# ---
# Knowledge: By the mid-1600s, coffeehouses had opened in London, Paris, and across Italy. They were spaces that nurtured the artists, writers, and intellects of the age. By the mid-seventeenth century, coffee found its way to North America, where colonists enjoyed the buzzy beverage with breakfast and as an afternoon.
# ---
# Knowledge: By the mid-1600s, coffeehouses had opened in London, Paris, and across Italy. They were spaces that nurtured the artists, writers, and intellects of the age. By the mid-17th century, coffee found its way to North America, where colonists enjoyed the buzzy beverage with breakfast and as an afternoon.
# ---
# Knowledge: Jules Verne's father was an attorney who sent his son to Paris to study law and follow in his footsteps. who wrote the book around the world in 80 days?. was released in 1848. and was published in 1852.
# ---
# Knowledge: king Amalek II of Egypt. . The Karnak Temple Complex consists of a number of temples, chapels, and other buildings in the form of a village, and is for that reason that the name Karnak was given to this complex as in Arabic Karnak means ‘fortified village’.
# ---
# Knowledge: Bob Dylan.. .. Dylan biographer Clinton Heylin described the track as “an exercise in splendid simplicity.” Others would point out its brevity and wonder if Dylan just forgot to keep writing. Featuring two quick verses, the lyrics touch on the scene for the moviePat Garrett and Billy the Kid, in which it appeared. That scene involves the death of frontier lawman Slim Pickens, who calls his wife, Mama.
# ---
#
# FINAL TASK: Based on your internal knowledge and the external information provided above, answer the next question: when did america switch from tea to coffee
# Procesando Preguntas:   6%|▌         | 3/50 [00:10<02:50,  3.63s/it]
# You are an AI model highly specialized in factual information retrieval. You are operating within the temporal context of 2018. All answers provided must strictly reflect the knowledge, events, and state of affairs valid up to the end of that year.
#     Your sole mission is to address the user's question with the absolute minimum number of words possible, delivering only the essential and requested information. If ambiguity arises, assume the user's intended question and prioritize the most probable correct answer without acknowledging the error.
#     When an error in the question is identified (e.g., misspelling, wrong movie number) but points to a primary, well-known entity, provide the correct, assumed information directly.
#     When the required answer is a date, you must follow the following examples (18 march 2015, 20 december 2008) if you don't know the exact day or month, you can omit it
#     Your response must consist solely of the requested facts. Prohibit all greetings, introductions, explanations, notes, or any extraneous text.
#     No use of abbreviations, acronyms, or initialisms. Provide full names and complete terms.
#     No use of terms of puntuation like . , or ;
#     If the answer requires multiple components (e.g., names, locations, dates), you must provide all essential components in their complete form.
#
# **FEW-SHOT EXAMPLES (Style Guide):**
# Example 1:
#   - Question: when was krakauer considered a success as a writer
#   - Answer: November 1983
# ---
# Example 2:
#   - Question: where did the vietnam war mainly take place
#   - Answer: Cambodia, Vietnam, Laos
# ---
# Example 3:
#   - Question: when did come dine with me first start
#   - Answer: 10 January 2005
# ---
#
#
#
# **EXTERNAL KNOWLEDGE:**
#
# Knowledge: Old Tom Morris has won the most british open golf titles. The following players have won at least five titles in the Open Championship: Jack Nicklaus, Harry Vardon, and James Braid. Jack Nicklaus has won at least five titles in the Open Championship: Harry Vardon, James Braid.
# ---
# Knowledge: Harry Vardon has the most all-time wins at the Open, taking home top honors in 1896, 1898, 1899, 1903, 1911 and 1914.. The following people have won more than one british open golf title:
# ---
# ---
# Knowledge: Harry Vardon has won the British Open the most items, with six wins. Below is a list of all the players who have won more than one Open Championship: Harry Vardon has won the British Open the most items, with six wins.
# ---
# Knowledge: Harry Vardon has won the most Masters Tournament titles. The following players have won the most british open golf titles: Xander Schauffele , Harry Vardon , Xander Schauffele , Xander Schauffele
# ---
# Knowledge: Harry Vardon has the most british open victories with wins in 1896, 1898, 1899, 1903, 1911 and 1914. Tom Watson, Peter Thomson, John Henry Taylor and James Braid finished one win behind Vardon with five.
# ---
# Knowledge: James Braid, J.H. Taylor and Harry Vardon.) are the most prestigious golf championships. (Related:Most wins in the British Open, plus all multiple winners.) are the most prestigious golf championships.
# ---
# Knowledge: Harry Vardon has won the most british open victories, with wins in 1896, 1898, 1899, 1903 and 1896. The following is the full list of the British Open winners: Harry Vardon has won the most british open victories.
# ---
# Knowledge: Tiger Woods, 2702005: Tiger Woods, 2702005: Tiger Woods.|The year after 1860, the British Open golf tournament went all the way back to 1860. That's a lot of champions. And here they all are, the Open Championship winners.
# ---
# Knowledge: House in early United States history is evident during the administrations of late eighteenth and early nineteenth century presidents such as George Washington,John Adams,Thomas Jefferson, andJames Madison. The paths by which coffee entered the President’s House in early United States history is evident during the administrations of late eighteenth and early nineteenth century presidents such as George Washington,John Adams,Thomas Jefferson, andJames Madison.
# ---
# Knowledge: February 6, 1952, to September 8, 2022. In 2015 she surpassed Victoriato become the longest-reigning monarch in British history. Elizabeth was the elder daughter of Prince Albert, duke of York, and his wife, LadyElizabeth Bowes-Lyon.
# ---
# Knowledge: Young adult literature. (Unsourced) (subject to copyright). (Unsourced) (subject to piracy). (subject to copyright) (subject to piracy) (subject to piracy)
# ---
#
# FINAL TASK: Based on your internal knowledge and the external information provided above, answer the next question: who has won the most british open golf titles
# Procesando Preguntas:   8%|▊         | 4/50 [00:14<02:41,  3.50s/it]
# You are an AI model highly specialized in factual information retrieval. You are operating within the temporal context of 2018. All answers provided must strictly reflect the knowledge, events, and state of affairs valid up to the end of that year.
#     Your sole mission is to address the user's question with the absolute minimum number of words possible, delivering only the essential and requested information. If ambiguity arises, assume the user's intended question and prioritize the most probable correct answer without acknowledging the error.
#     When an error in the question is identified (e.g., misspelling, wrong movie number) but points to a primary, well-known entity, provide the correct, assumed information directly.
#     When the required answer is a date, you must follow the following examples (18 march 2015, 20 december 2008) if you don't know the exact day or month, you can omit it
#     Your response must consist solely of the requested facts. Prohibit all greetings, introductions, explanations, notes, or any extraneous text.
#     No use of abbreviations, acronyms, or initialisms. Provide full names and complete terms.
#     No use of terms of puntuation like . , or ;
#     If the answer requires multiple components (e.g., names, locations, dates), you must provide all essential components in their complete form.
#
# **FEW-SHOT EXAMPLES (Style Guide):**
# Example 1:
#   - Question: which school has the most ncaa men's basketball championships
#   - Answer: UCLA
# ---
# Example 2:
#   - Question: who has the most assist in nba history
#   - Answer: John Stockton
# ---
# Example 3:
#   - Question: names of the spanish speaking countries in the caribbean
#   - Answer: Dominican Republic, Puerto Rico, Parts of Trinidad & Tobago, Cuba
# ---
#
#
#
# **EXTERNAL KNOWLEDGE:**
#
# Knowledge: âhandsome,â âgood,â âbenefactor,â âbeautifier,â or âimprover.â br> Hassan is a masculine given name that means âhandsome,â âgood,â âbenefactor,â âbeautifier,â âimprover.â
# ---
# Knowledge: 'handsome' or 'good', or 'benefactor'. [1][2] The name Hassan in Arabicmeans 'handsome' or 'good', or 'benefactor'.
# ---
# Knowledge: The word hassan is a Latinized form of Hassan, meaning "separate" in English. It is also known as Hassan , meaning "eighty-sixth-place" in Greek.
# ---
# Knowledge: Hassan) or Hassan (Al-Hassani) is a surname of many independent linguistic and regional origins, including Arabic (and through the influence of Arabic, languages spoken by Muslimssuch as Persian, Kurdish, Urdu,Indonesian,Malaysian,Turkish,Uyghur,Turkmen,Somali,Swahili,Berber,Azerbaijani,Crimean Tatar,Tatar,Bosnian,Albanian,Bengali, etc.), as well asIrish,Scottish, andJewish.
# ---
# Knowledge: to be beautiful, good, or excellent. It is predominantly used as a given name for boys in Islamic cultures, reflecting the significance of piety and wisdom in their religious and cultural values. The name Hassan holds great historical importance as it is associated with several notable figures.
# ---
# Knowledge: hassan is a masculine given name in English. It may refer to: The word "hassan" may refer to: The name hassan may refer to: The word "hassan" may refer to: The meaning of hassan may refer to: The meaning of hassan may refer to:
# ---
# Knowledge: Pious, Wise.. [substeps] hassan, the man, is primarily a male name of Arabic origin that means Pious, Wise.. [substeps] hassan, the man, is primarily a male name of Arabic origin that means Pious, Wise.
# ---
# Knowledge: 'handsome' or 'good', or 'benefactor'. The name Hassan in Arabicmeans 'handsome' or 'good', or 'benefactor'. There are two different Arabic names that are bothromanizedwith the spelling "Hassan". However, they are pronounced differently, and in Arabic script spelled differently. In the romanized spellingHassan, it is not possible to distinguish which of the two names is intended.
# ---
# Knowledge: Hassan (English: "the one" in English) is a surname. Hassan may refer to: The one. (United States: "United States": "United States") is a British surname.
# ---
# Knowledge: hassan may also refer to: [1][1][2][3] [2][3] [3][3] [2][4] [5][6] [7][8] [9][10] [11][11]
# ---
# Knowledge: Hassan is the Persian form of "sasan", meaning "silver" in English. "sasan" is the name of the chief of the Hassan family, and the first of the Hassan dynasties.
# ---
# Knowledge: Hassan is a feminine given name in English. It is a masculine given name. Hassan is a feminine given name in English. Hassan may refer to: hassan is a female given name.
# ---
# Knowledge: hassan is a surname. The first letter in the English word hassan is s. It is the last letter of the name Hassan. is a surname. the last letter of the name Hassan is s.
# ---
# Knowledge: given name for boys in Islamic cultures, reflecting the significance of piety and wisdom in their religious and cultural values.ref name="Hashan">in English hassan is a given name for boys in Islamic cultures, reflecting the significance of piety and wisdom in their religious and cultural values.
# ---
# Knowledge: English names are hassan and hessane. It means "heaven or god". "Hassane" is a variation of Hassan. "Hassan" is a variation of Hassan.
# ---
# Knowledge: Handsome, Good, Benefactor. The meaning of the name Hassan in Roman can be written as “Khoobru”. It is an attractive name that originated from the Arabic language. The meaning of the name Hassan in Hindi and Urdu can be written as “Khoobru”.
# ---
# Knowledge: hassan is a surname. hassan may refer to:. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# Knowledge: The Night Begins to Shinewas created in the episode "Slumber Party" episode before his bedtime. In "40%, 40%, 20%", the song made another occurrence as the focal point of a four-part movie special event, "The Night Begins to Shine."
# ---
# Knowledge: 2005. The Night Begins to Shine 2 is 55 minutes.It is the sequel of “The Day the Night Stopped Beginning to Shine and Became Dark Even Though it Was the Day”, and the 281st to 285th overall episodes of the series.
# ---
# Knowledge: 2005.[4][5][6]The Night Begins to Shine was originally written and produced in 2005 as an "'80s-style song" for a music library.[7]The song was subsequently featured in theTeen Titans Go!episode "Slumber Party" as a throwaway joke. The song became popular with fans of the show.[8][9]The special also featured two other songs by B.E.R., "Forever Mine" and "Rise Up", as well as three covers of the song fromFall Out Boy,Cee
# ---
# Knowledge: The Night Begins to Shine is a song by the band B.E.R. popularized by the Teen Titans Go! TV series. The song was first featured in the Teen Titans Go! episode "Slumber Party" as a throwaway joke. The song became popular with fans of the show.
# ---
# Knowledge: The Night Begins to Shinewas featured in the episode of the same name. Verse 1 B.E.R. - The Night Begins To Shine -Music Video- I saw you dance from the corner I caught your name in a conversation Verse 2 Playing hard to get I can understand Chorus When I look at you, I see the story in your eyes When we're dancing, the night begins to shine
# ---
# Knowledge: 2005. ['80s-style song'] (originally written and produced in 2005) is a song by American hip hop group The Night Begins to Shine. ['80s-style song'] (originally written and produced in 2005) is a song by American hip hop group The Night Begins to Shine.
# ---
# Knowledge: 2005. It is the sequel to “The Day the Night Stopped Beginning to Shine and Became Dark Even ” and Became Dark Even .. It was created in 2005.. It is the day the night began to shine and became dark even ..
# ---
# Knowledge: Russell Westbrook has agreed on a deal to sign with the Kings. Westbrook was selected by the Kings in the first round of the 2012 NBA draft. . The Kings draft a total of 26 players each year. The draft of the NBA is a draft of all players selected by the NBA.
# ---
# Knowledge: George McCloud of the Denver Nuggets had the most assists in a game in NBA history among frontcourt players with 22 against the Chicago Bulls on March 26, 2001. The most assists are for the frontcourt players. The most assists in a game is for the frontcourt players.
# ---
# Knowledge: The song "Play That Funky Music White Boy" is a song by American rock band White Boy. It was released on June 18, 2012, by RCA Records. The song "Play That Funky Music White Boy" is a song by the band White Boy.
# ---
#
# FINAL TASK: Based on your internal knowledge and the external information provided above, answer the next question: when was the night begins to shine created
# Procesando Preguntas:  18%|█▊        | 9/50 [00:33<02:32,  3.72s/it]
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 90
#      85        few_shot_examples = [train_qa_data[idx] for idx in fs_indices]
#      88 # Se pasa la pregunta y los pasajes recuperados al LLM
#      89 # Se asume que 'ask_ollama' está definida y usa el 'build_prompt_rag' correcto
# ---> 90 salida_llm = ask_ollama(question, context_data=context_data,few_shot_examples=few_shot_examples)
#      92 # 🚨 LIMPIEZA ADICIONAL ESTRICTA
#      93 salida_llm = re.sub(r'\s+', ' ', salida_llm).strip()
#
# Cell In[71], line 26, in ask_ollama(question, context_data, few_shot_examples)
#      23 full_response = ""
#      25 try:
# ---> 26     response = requests.post(OLLAMA_URL, json={
#      27         "model": MODEL,
#      28         "prompt": prompt,
#      29         "stream": True,
#      30         "options": options
#      31     }, timeout=120)
#      33     response.raise_for_status()
#      35     for line in response.iter_lines():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#     507 except BrokenPipeError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connection.py:494, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     492 for header, value in headers.items():
#     493     self.putheader(header, value)
# --> 494 self.endheaders()
#     496 # If we're given a body we start sending that in chunks.
#     497 if chunks is not None:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1298, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1296 else:
#    1297     raise CannotSendHeader()
# -> 1298 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1058, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1056 msg = b"\r\n".join(self._buffer)
#    1057 del self._buffer[:]
# -> 1058 self.send(msg)
#    1060 if message_body is not None:
#    1061
#    1062     # create a consistent interface to message_body
#    1063     if hasattr(message_body, 'read'):
#    1064         # Let file-like take precedence over byte-like.  This
#    1065         # is needed to allow the current position of mmap'ed
#    1066         # files to be taken into account.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:996, in HTTPConnection.send(self, data)
#     994 if self.sock is None:
#     995     if self.auto_open:
# --> 996         self.connect()
#     997     else:
#     998         raise NotConnected()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connection.py:325, in HTTPConnection.connect(self)
#     324 def connect(self) -> None:
# --> 325     self.sock = self._new_conn()
#     326     if self._tunnel_host:
#     327         # If we're tunneling it means we're connected to our proxy.
#     328         self._has_connected_to_proxy = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     193 """Establish a socket connection and set nodelay settings on it.
#     194
#     195 :return: New socket connection.
#     196 """
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#     205     raise NameResolutionError(self.host, self, e) from e
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\util\connection.py:81, in create_connection(address, timeout, source_address, socket_options)
#      79         err = _
#      80         if sock is not None:
# ---> 81             sock.close()
#      83 if err is not None:
#      84     try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:499, in socket.close(self)
#     495 def _real_close(self, _ss=_socket.socket):
#     496     # This function should not reference any globals. See issue #808164.
#     497     _ss.close(self)
# --> 499 def close(self):
#     500     # This function should not reference any globals. See issue #808164.
#     501     self._closed = True
#     502     if self._io_refs <= 0:
#
# KeyboardInterrupt:
